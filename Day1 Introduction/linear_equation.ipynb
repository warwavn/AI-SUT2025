# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,20) #Gen 20 value between -10 to 10 
print(x)
# Out:
# [-10.          -8.94736842  -7.89473684  -6.84210526  -5.78947368
#   -4.73684211  -3.68421053  -2.63157895  -1.57894737  -0.52631579
#    0.52631579   1.57894737   2.63157895   3.68421053   4.73684211
#    5.78947368   6.84210526   7.89473684   8.94736842  10.        ]

# %%
m = 1
c = 1

# %%
y = c + m*x

# %%
print(y)
# Out:
# [-9.         -7.94736842 -6.89473684 -5.84210526 -4.78947368 -3.73684211
#  -2.68421053 -1.63157895 -0.57894737  0.47368421  1.52631579  2.57894737
#   3.63157895  4.68421053  5.73684211  6.78947368  7.84210526  8.89473684
#   9.94736842 11.        ]

# %%
plt.plot(x,y)

plt.xlabel('x value')
plt.ylabel('y value')
# plt.title('y = mx + c')
plt.grid()
plt.show()

# %% [markdown]
# Quiz: from y=mx+c write the program to plot linear that has c = -5 and pass P1(-6,-3) & P2(8,7)
# can use python code for cal

# %%
x = np.linspace(-10,10,20) #Gen 20 value between -10 to 10 
print(x)
# Out:
# [-10.          -8.94736842  -7.89473684  -6.84210526  -5.78947368
#   -4.73684211  -3.68421053  -2.63157895  -1.57894737  -0.52631579
#    0.52631579   1.57894737   2.63157895   3.68421053   4.73684211
#    5.78947368   6.84210526   7.89473684   8.94736842  10.        ]

# %%
# Given points
x1, y1 = -6, -3
x2, y2 = 8, 7

# Calculate the slope (m)
m = (y2 - y1) / (x2 - x1)

# Calculate the y-intercept (c)
c = y1 - m * x1

# Display the results
print(f"The slope (m) is: {m}")
print(f"The y-intercept (c) is: {c}")
# Out:
# The slope (m) is: 0.7142857142857143
# The y-intercept (c) is: 1.2857142857142856

# %%
y = c + m*x

# %%
# markers_on = [-6, -3, 8, 7]
# plt.plot(x,y, '-gD', markevery=markers_on)
x_mark = -6,8
y_mark = -3,7
plt.plot(x,y)

plt.scatter(x_mark, y_mark, color='red', label=f"Point ({x_mark}, {y_mark})")

plt.grid()

# %% [markdown]
# Multi variable linear equation

# %%
a = np.linspace(-10,10,20)
b = np.linspace(-3,3,20)

z = 1 + 2*a+3*b

print("a",a)
print("b",b)
print("z",z)
# Out:
# a [-10.          -8.94736842  -7.89473684  -6.84210526  -5.78947368
#   -4.73684211  -3.68421053  -2.63157895  -1.57894737  -0.52631579
#    0.52631579   1.57894737   2.63157895   3.68421053   4.73684211
#    5.78947368   6.84210526   7.89473684   8.94736842  10.        ]
# b [-3.         -2.68421053 -2.36842105 -2.05263158 -1.73684211 -1.42105263
#  -1.10526316 -0.78947368 -0.47368421 -0.15789474  0.15789474  0.47368421
#   0.78947368  1.10526316  1.42105263  1.73684211  2.05263158  2.36842105
#   2.68421053  3.        ]
# z [-28.         -24.94736842 -21.89473684 -18.84210526 -15.78947368
#  -12.73684211  -9.68421053  -6.63157895  -3.57894737  -0.52631579
#    2.52631579   5.57894737   8.63157895  11.68421053  14.73684211
#   17.78947368  20.84210526  23.89473684  26.94736842  30.        ]

# %%
a_new,b_new = np.meshgrid(a,b)
z = 1 + 2*a_new+3*b_new
fig = plt.figure()   #set fig for 3D - default 2D plt
ax = plt.axes(projection = '3d')
ax.plot_surface(a_new,b_new,z)
