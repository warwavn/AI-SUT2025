# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-10,10,20)

y= x**5 + 3*x**4 - 4*x**3 + x**2 + 2*x + 3

# %% [markdown]
# min,max point by local/global

# %%
plt.plot(x,y)
plt.grid()
