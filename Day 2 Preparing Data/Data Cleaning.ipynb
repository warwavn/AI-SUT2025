# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\ex_missing_value - ex_missing_value.csv")
df
# Out:
#             car   color  volume  weight  co2
# 0   Honda Civic     Red  1600.0  1252.0   94
# 1  Suzuki Swift   White  1300.0     NaN  101
# 2       Mazda 3   Black     NaN  1280.0  104
# 3      Benz CLA   Black     NaN  1465.0  102
# 4   Mini Cooper     Red  1500.0     NaN  105
# 5    Ford Focus    Blue  2000.0  1328.0  105
# 6  Benz C-Class  Silver     NaN  1365.0   99
# 7  Benz E-Class   While  2100.0  1605.0  115
# 8   Ford Fiesta     Red  1500.0  1112.0   98
# 9    Volvo XC70  Silver  2000.0  1746.0  117

# %%
check_null = df.isnull().any()

print(check_null)
# Out:
# car       False
# color     False
# volume     True
# weight     True
# co2       False
# dtype: bool

# %%
nmissing = df.isnull().sum()

print(nmissing)
# Out:
# car       0
# color     0
# volume    3
# weight    2
# co2       0
# dtype: int64

# %%
# df.dropna(inplace=True) -- overwrite
df_drop = df.dropna()
df_drop
# Out:
#             car   color  volume  weight  co2
# 0   Honda Civic     Red  1600.0  1252.0   94
# 5    Ford Focus    Blue  2000.0  1328.0  105
# 7  Benz E-Class   While  2100.0  1605.0  115
# 8   Ford Fiesta     Red  1500.0  1112.0   98
# 9    Volvo XC70  Silver  2000.0  1746.0  117

# %% [markdown]
# fillna\
# avg\
# desired\
# klai kiang

# %%
df_fill = df.fillna(0)
df_fill
# Out:
#             car   color  volume  weight  co2
# 0   Honda Civic     Red  1600.0  1252.0   94
# 1  Suzuki Swift   White  1300.0     0.0  101
# 2       Mazda 3   Black     0.0  1280.0  104
# 3      Benz CLA   Black     0.0  1465.0  102
# 4   Mini Cooper     Red  1500.0     0.0  105
# 5    Ford Focus    Blue  2000.0  1328.0  105
# 6  Benz C-Class  Silver     0.0  1365.0   99
# 7  Benz E-Class   While  2100.0  1605.0  115
# 8   Ford Fiesta     Red  1500.0  1112.0   98
# 9    Volvo XC70  Silver  2000.0  1746.0  117

# %%
df['weight'].fillna(df['weight'].mean(), inplace=True)
df['volume'].fillna(df['volume'].mean(), inplace=True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_42712\3465217214.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weight'].fillna(df['weight'].mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_42712\3465217214.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ffill forward fill\
# bfill back fill

# %%
df['weight'].fillna(method='ffill', inplace=True)
df['volume'].fillna(method='bfill', inplace=True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_42712\993515098.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weight'].fillna(method='ffill', inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_42712\993515098.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['weight'].fillna(method='ffill', inplace=True)
# ...

# %%
df['weight'].ffill(inplace=True)
# df['volume'].fillna(method='bfill', inplace=True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_42712\1939332040.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weight'].ffill(inplace=True)
#             car   color  volume  weight  co2
# 0   Honda Civic     Red  1600.0  1252.0   94
# 1  Suzuki Swift   White  1300.0  1252.0  101
# 2       Mazda 3   Black  1500.0  1280.0  104
# 3      Benz CLA   Black  1500.0  1465.0  102
# 4   Mini Cooper     Red  1500.0  1465.0  105
# 5    Ford Focus    Blue  2000.0  1328.0  105
# 6  Benz C-Class  Silver  2100.0  1365.0   99
# ...
