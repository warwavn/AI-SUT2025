# %%
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\k-means - k-means.csv")
silhouette_avgs = []
min_k = 2
max_k = len(df) # using len(df) for All possible ‘K’
for k in range(min_k, max_k):
    model = KMeans(n_clusters=k,random_state=0).fit(df)
    s_score = metrics.silhouette_score(df, model.labels_)
    print('Silhouette Coeff for k =', k, 'is', s_score)
    silhouette_avgs.append(s_score)
    
optimal_k = silhouette_avgs.index(max(silhouette_avgs)) + min_k
print('Optimal K is ', optimal_k)
plt.plot(range(min_k, max_k), silhouette_avgs)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Coefficient')
plt.xticks(range(min_k, max_k))
plt.show()
# Out:
# Silhouette Coeff for k = 2 is 0.5051959802345012
# Silhouette Coeff for k = 3 is 0.5107383117230143
# Silhouette Coeff for k = 4 is 0.4480846057409834
# Silhouette Coeff for k = 5 is 0.43116909607087694
# Silhouette Coeff for k = 6 is 0.4860676829904247
# Silhouette Coeff for k = 7 is 0.4727516100080185
# Silhouette Coeff for k = 8 is 0.4979798159711021
# Silhouette Coeff for k = 9 is 0.5612456481793094
# Silhouette Coeff for k = 10 is 0.5510326445505243
# Silhouette Coeff for k = 11 is 0.5338981039459495
# Silhouette Coeff for k = 12 is 0.5261448391733822
# Silhouette Coeff for k = 13 is 0.5022412045371225
# Silhouette Coeff for k = 14 is 0.4732170870457388
# Silhouette Coeff for k = 15 is 0.4472142015634051
# Silhouette Coeff for k = 16 is 0.3979742876279847
# Silhouette Coeff for k = 17 is 0.37076042720689084
# Silhouette Coeff for k = 18 is 0.34781226045357544
# Silhouette Coeff for k = 19 is 0.3233180774489037
# Silhouette Coeff for k = 20 is 0.3183881758400858
# Silhouette Coeff for k = 21 is 0.27058207847966453
# Silhouette Coeff for k = 22 is 0.2584609696324043
# Silhouette Coeff for k = 23 is 0.21467993133276037
# Silhouette Coeff for k = 24 is 0.22080540994386902
# Silhouette Coeff for k = 25 is 0.19777563788666647
# Silhouette Coeff for k = 26 is 0.14675691382494177
# Silhouette Coeff for k = 27 is 0.11969038561569846
# Silhouette Coeff for k = 28 is 0.07875246371526007
# Silhouette Coeff for k = 29 is 0.0325104065896652
# Optimal K is  9

# %%
sum_of_sqared_distance = []
mink = 2
maxk = len(df)

for k in range(mink,maxk):
    model = KMeans(n_clusters=k)
    model.fit(df)
    sum_of_sqared_distance.append(model.inertia_)

plt.plot(range(mink,maxk),sum_of_sqared_distance)
