# %%
import cv2
import matplotlib.pyplot as plt

# %%
import cv2
gray_img = cv2.imread("gradient.png")
thresh,th1 = cv2.threshold(gray_img,128,255,cv2.THRESH_BINARY)
# thresh,th12 = cv2.threshold(gray_img,200,255,cv2.THRESH_BINARY)
thresh,th2 = cv2.threshold(gray_img,128,255,cv2.THRESH_BINARY_INV)
thresh,th3 = cv2.threshold(gray_img,128,255,cv2.THRESH_TRUNC)
thresh,th4 = cv2.threshold(gray_img,128,255,cv2.THRESH_TOZERO)
thresh,th5 = cv2.threshold(gray_img,128,255,cv2.THRESH_TOZERO_INV)

cv2.imshow("Orignal",gray_img)
cv2.imshow("BINARY",th1)
# cv2.imshow("BINARY2",th12)


cv2.imshow("BINARY_INV",th2)
cv2.imshow("TRUNC",th3)
cv2.imshow("TOZERO",th4)
cv2.imshow("TOZERO_INV",th5)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
gray_img = cv2.imread("gradient.png")
thresh,th1 = cv2.threshold(gray_img,128,255,cv2.THRESH_BINARY)
# thresh,th12 = cv2.threshold(gray_img,200,255,cv2.THRESH_BINARY)
thresh,th2 = cv2.threshold(gray_img,128,255,cv2.THRESH_BINARY_INV)
thresh,th3 = cv2.threshold(gray_img,128,255,cv2.THRESH_TRUNC)
thresh,th4 = cv2.threshold(gray_img,128,255,cv2.THRESH_TOZERO)
thresh,th5 = cv2.threshold(gray_img,128,255,cv2.THRESH_TOZERO_INV)

images = [gray_img,th1,th2,th3,th4,th5]
titles = ["Original",'Binary','Binary_inv','TRUNC','TOZERO','TOZERO_INV']

for i in range(len(images)):
    plt.subplot(2,3,i+1)            #row,col,index+1
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])

plt.show()

# %%
img = cv2.imread("kid.jpg")
gray_kids = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

th_val = [50,100,128,200,230]
plt.subplot(231,xticks= [], yticks= [])         #(row,col,pos) = (2,3,1)
plt.title("Original")
plt.imshow(gray_kids,cmap = 'gray')

for i in range(len(th_val)):
    th, result = cv2.threshold(gray_kids,th_val[i],255,cv2.THRESH_BINARY)
    plt.subplot(232+i)
    plt.title("%d"%th_val[i])
    plt.imshow(result,cmap='gray')
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# Threshold Value (Trackbar)

# %%
def display(value):
    # print("Threshold value =",value)
    pass
cv2.namedWindow("Output")
cv2.createTrackbar("value","Output",0,255,display)

while(True):
    img = cv2.imread("kid.jpg")
    gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    th_val = cv2.getTrackbarPos("value","Output")
    thresh,result = cv2.threshold(gray_img,th_val,255,cv2.THRESH_BINARY)
    
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
    cv2.imshow("Output",result)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 10
#       8 img = cv2.imread("kid.jpg")
#       9 gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# ---> 10 th_val = cv2.getTrackbarPos("value","Output")
#      11 thresh,result = cv2.threshold(gray_img,th_val,255,cv2.THRESH_BINARY)
#      13 if cv2.waitKey(1) & 0xFF == ord('x'):
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:868: error: (-215:Assertion failed) trackbar in function 'cv::getTrackbarPos'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
img = cv2.imread("kid.jpg",0)

thresh, th1 = cv2.threshold(img,128,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,3,1)           #blocksize = 3, c=1
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,3,1)  


cv2.imshow("Original",img)
cv2.imshow("BINIRY",th1)
cv2.imshow("Adaptive Mean",th2)
cv2.imshow("Adaptive Gaussian",th3)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
size = [3,5,9,17,33]
plt.subplot(321,xticks=[],yticks=[])
plt.title("Original GrayScale")
plt.imshow(img,cmap="gray")

for i in range(len(size)):
    result = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,size[i],1)
    plt.subplot(322+i)
    plt.title("%d"%size[i])
    plt.imshow(result,cmap="gray")
    plt.xticks([]),plt.yticks([])
plt.show()
