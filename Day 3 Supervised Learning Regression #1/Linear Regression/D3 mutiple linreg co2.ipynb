# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\co2-emission - co2-emission.csv")
df.head()
# Out:
#           car       model  volume  weight  co2
# 0      Toyota        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
x1 = df['volume']
x2 = df['weight']
y  = df['co2']

# %%
plt.scatter(x1,y)
plt.xlabel("Volume")
plt.ylabel("co2")
plt.grid()

# %%
plt.scatter(x2,y,color = 'g')
plt.xlabel("Weight")
plt.ylabel("co2")
plt.grid()

# %%
x = df[['volume','weight']]
y = df['co2']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(x_train,y_train)

y_predict_train = model.predict(x_train)

y_predict_test = model.predict(x_test)

# %% [markdown]
# Evaluate Training Model

# %%
r2_train = model.score(x_train,y_train)
mse_train = mean_squared_error(y_train,y_predict_train)
rmse_train = np.sqrt(mse_train)

print("=== Training Set ===")
print(f"R2 = {r2_train:,.2f}")
print(f"MSE = {mse_train:,.2f}")
print(f"RMSE = {rmse_train:,.2f}")


r2_test = model.score(x_test,y_test)
mse_test = mean_squared_error(y_test,y_predict_test)
rmse_test = np.sqrt(mse_test)

print("=== Test Set ===")
print(f"R2 = {r2_test:,.2f}")
print(f"MSE = {mse_test:,.2f}")
print(f"RMSE = {rmse_test:,.2f}")
# Out:
# === Training Set ===
# R2 = 0.36
# MSE = 31.55
# RMSE = 5.62
# === Test Set ===
# R2 = 0.41
# MSE = 41.49
# RMSE = 6.44

# %% [markdown]
# Engine size = 3200 L, Weight = 2500 kg, CO emission =?

# %%
xx = [[3200,2500]]

yy = model.predict(xx)

for (i,x_p) in enumerate(yy):
    co2 = '{:,.0f}'.format(yy[i])
    print(f" CO emission = {co2} kg/L")
# Out:
#  CO emission = 123 kg/L
# c:\Users\User\Desktop\test\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
